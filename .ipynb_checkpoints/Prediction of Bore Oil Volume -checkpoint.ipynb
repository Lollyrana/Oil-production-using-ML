# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import seaborn as sn

newdf = pd.read_excel('Volve production data.xlsx')

# %%
#Roundinf off the data to the nearest integer
newdf = np.round(newdf)

# %%
#Data is highly skewed and depends on the well,hence i have used padding to fill the missing values 
newdf['ON_STREAM_HRS'] = newdf['ON_STREAM_HRS'].fillna(method='pad')

newdf['AVG_DOWNHOLE_PRESSURE'] = newdf['AVG_DOWNHOLE_PRESSURE'].fillna(method='pad')

newdf['AVG_DOWNHOLE_TEMPERATURE'] = newdf['AVG_DOWNHOLE_TEMPERATURE'].fillna(method='pad')

newdf['AVG_DP_TUBING'] = newdf['AVG_DP_TUBING'].fillna(method='pad')

newdf['AVG_ANNULUS_PRESS'] = newdf['AVG_ANNULUS_PRESS'].fillna(method='pad')

newdf['AVG_CHOKE_SIZE_P'] = newdf['AVG_CHOKE_SIZE_P'].fillna(method='pad')

newdf['AVG_WHP_P'] = newdf['AVG_WHP_P'].fillna(method='pad')

newdf['AVG_WHT_P'] = newdf['AVG_WHT_P'].fillna(method='pad')

newdf['DP_CHOKE_SIZE'] = newdf['DP_CHOKE_SIZE'].fillna(method='pad')

newdf['BORE_OIL_VOL'] = newdf['BORE_OIL_VOL'].fillna(method='pad')

newdf['BORE_GAS_VOL'] = newdf['BORE_GAS_VOL'].fillna(method='pad')

newdf['BORE_WAT_VOL'] = newdf['BORE_WAT_VOL'].fillna(method='pad')

# %%
data = 
  
# setting the parameter values
annot = True
  
# plotting the heatmap
hm = sn.heatmap(data=data,
                annot=annot)
  
# displaying the plotted heatmap
plt.show()

# %%
to_drop = ["WELL_BORE_CODE", "NPD_WELL_BORE_NAME", "NPD_FIELD_NAME", "NPD_FIELD_CODE", "NPD_FACILITY_CODE", "NPD_FACILITY_NAME","AVG_DOWNHOLE_PRESSURE", "AVG_DP_TUBING","BORE_WI_VOL","AVG_CHOKE_UOM","FLOW_KIND","WELL_TYPE","BORE_GAS_VOL"]
newdf = newdf.drop(to_drop, axis=1)
print(newdf.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15634 entries, 0 to 15633
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DATEPRD                   15634 non-null  datetime64[ns]
#  1   NPD_WELL_BORE_CODE        15634 non-null  int64
#  2   ON_STREAM_HRS             15634 non-null  float64
#  3   AVG_DOWNHOLE_TEMPERATURE  15634 non-null  float64
#  4   AVG_ANNULUS_PRESS         15634 non-null  float64
#  5   AVG_CHOKE_SIZE_P          15634 non-null  float64
#  6   AVG_WHP_P                 15634 non-null  float64
#  7   AVG_WHT_P                 15634 non-null  float64
#  8   DP_CHOKE_SIZE             15634 non-null  float64
#  9   BORE_OIL_VOL              15634 non-null  float64
#  10  BORE_WAT_VOL              15634 non-null  float64
# dtypes: datetime64[ns](1), float64(9), int64(1)
# memory usage: 1.3 MB
# None

# %%
dataplot = sn.heatmap(newdf.corr(numeric_only=False), cmap="YlGnBu", annot=True)
  
# displaying heatmap
plt.show()

# %%
#Scaling dataset to remove difference in distributions within columns

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

newdf[['ON_STREAM_HRS','AVG_DOWNHOLE_TEMPERATURE','AVG_ANNULUS_PRESS','AVG_CHOKE_SIZE_P','AVG_WHP_P','AVG_WHT_P']] = scaler.fit_transform(newdf[['ON_STREAM_HRS', 'AVG_DOWNHOLE_TEMPERATURE','AVG_ANNULUS_PRESS', 'AVG_CHOKE_SIZE_P','AVG_WHP_P', 'AVG_WHT_P']])


#Taking the data of wells 2 to 4 since they were the ones with the east number of missing values
fdf = newdf.loc[746 : 8022]

X = fdf.drop(['BORE_OIL_VOL'],axis=1)
y= fdf[['BORE_OIL_VOL','NPD_WELL_BORE_CODE']]

#Applying Linear Regression

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size = 0.3, random_state=42)

reg_all = LinearRegression()

# %%
x_train_final = X_train.drop(['DATEPRD','NPD_WELL_BORE_CODE'],axis = 1)
x_test_final = X_test.drop(['DATEPRD',"NPD_WELL_BORE_CODE"],axis = 1)

# %%
y_test_final = y_test['BORE_OIL_VOL']
y_train_final = y_train['BORE_OIL_VOL']

# %%
X = fdf.drop(['DATEPRD','BORE_OIL_VOL'],axis=1).values
y= fdf['BORE_OIL_VOL']

# %%
x_train_final
# Out:
#       ON_STREAM_HRS  AVG_DOWNHOLE_TEMPERATURE  AVG_ANNULUS_PRESS  \
# 3374           0.96                  0.000000           0.433333
# 3760           0.96                  0.000000           0.500000
# 2900           0.96                  0.000000           0.766667
# 2090           0.96                  0.972477           0.400000
# 7782           0.96                  0.917431           0.466667
# ...             ...                       ...                ...
# 5937           0.96                  0.972477           0.000000
# 5972           0.96                  0.972477           0.000000
# 6136           0.92                  0.954128           0.000000
# 1606           0.96                  0.972477           0.366667
# 8016           0.00                  0.000000           0.366667
#
#       AVG_CHOKE_SIZE_P  AVG_WHP_P  AVG_WHT_P  DP_CHOKE_SIZE  BORE_WAT_VOL
# 3374              1.00   0.248175   0.978723            5.0        4663.0
# 3760              1.00   0.240876   0.968085            4.0        4630.0
# 2900              0.56   0.350365   0.936170           16.0        3784.0
# 2090              0.50   0.605839   0.840426           49.0           7.0
# 7782              0.94   0.211679   0.925532            2.0        3346.0
# ...                ...        ...        ...            ...           ...
# 5937              0.62   0.335766   0.968085           13.0        3374.0
# 5972              1.00   0.299270   0.957447            9.0        3359.0
# 6136              0.57   0.306569   0.946809           12.0        4301.0
# 1606              1.00   0.233577   0.861702            5.0        2145.0
# 8016              0.01   0.080292   0.000000            9.0           0.0
#
# [5093 rows x 8 columns]

# %%
reg_all.fit(x_train_final, y_train_final)
# Out:
# LinearRegression()

# %%
y_pred = reg_all.predict(x_test_final)

# %%
print("The R2 value for linear regression for oil volume production is", reg_all.score(x_test_final, y_test_final))
# Out:
# The R2 value for linear regression for oil volume production is 0.5542109655694197

# %%
importance = reg_all.coef_
# summarize feature importance
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
# Out:
# Feature: 0, Score: 1338.07639
# Feature: 1, Score: 280.89200
# Feature: 2, Score: -1194.43707
# Feature: 3, Score: 48.02134
# Feature: 4, Score: 506.57085
# Feature: 5, Score: 2572.30477
# Feature: 6, Score: 13.05541
# Feature: 7, Score: -0.40973

# %%
reg_all.coef_
# Out:
# array([ 1.33807639e+03,  2.80892004e+02, -1.19443707e+03,  4.80213352e+01,
#         5.06570847e+02,  2.57230477e+03,  1.30554129e+01, -4.09730530e-01])

# %%
reg_all.intercept_
# Out:
# -1110.702698660846

# %% [markdown]
# ### Correlation from Linear Regression

# %%
print("The Correlation from linear model is: BORE_OIL_VOL = {:.5} + {:.5}*ON_STREAM_HRS + {:.5}*AVG_DOWNHOLE_TEMPERATURE  {:.5}*AVG_ANNULUS_PRESS + {:.5}*AVG_CHOKE_SIZE_P + {:.5}*AVG_WHP_P + {:.5}*AVG_WHT_P + {:.5}*DP_CHOKE_SIZE {:.5}*BORE_WAT_".format(reg_all.intercept_, reg_all.coef_[0], reg_all.coef_[1], reg_all.coef_[2],reg_all.coef_[3], reg_all.coef_[4], reg_all.coef_[5], reg_all.coef_[6], reg_all.coef_[7]))
# Out:
# The Correlation from linear model is: BORE_OIL_VOL = -1110.7 + 1338.1*ON_STREAM_HRS + 280.89*AVG_DOWNHOLE_TEMPERATURE  -1194.4*AVG_ANNULUS_PRESS + 48.021*AVG_CHOKE_SIZE_P + 506.57*AVG_WHP_P + 2572.3*AVG_WHT_P + 13.055*DP_CHOKE_SIZE -0.40973*BORE_WAT_

# %% [markdown]
# ### Polynomial

# %%
# Applying Polynomisl Regression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(x_train_final)
lin_reg = LinearRegression()
lin_reg.fit(X_poly, y_train_final)
x_pol_test = poly_reg.fit_transform(x_test_final)
X_poly.shape[1]



print("The R2 value for Ridge regression for oil volume production is",lin_reg.score(x_pol_test, y_test_final))
# Out:
# The R2 value for Ridge regression for oil volume production is 0.9572677127294036

# %%
a =np.array(poly_reg.get_feature_names_out(['ON_STREAM_HRS','AVG_DOWNHOLE_TEMPERATURE', 'AVG_ANNULUS_PRESS', 'AVG_CHOKE_SIZE_P','AVG_WHP_P','AVG_WHT_P','DP_CHOKE_SIZE' ,'BORE_WAT_VOL']))

# %%
print(len(a))
# Out:
# 495

# %%
b = np.array(lin_reg.coef_)

# %%
Correlation_Poly = pd.DataFrame({'Coefficients':b, 'Feature Name':a})

# %%
pd.set_option('display.max_rows',30)

# %%
Correlation_Poly.head(30)
# Out:
#     Coefficients                                Feature Name
# 0      51.272236                                           1
# 1      98.312136                               ON_STREAM_HRS
# 2      -2.268094                    AVG_DOWNHOLE_TEMPERATURE
# 3     -33.306440                           AVG_ANNULUS_PRESS
# 4      75.994927                            AVG_CHOKE_SIZE_P
# 5      21.827586                                   AVG_WHP_P
# 6      49.877757                                   AVG_WHT_P
# 7     -15.096760                               DP_CHOKE_SIZE
# 8      24.140095                                BORE_WAT_VOL
# 9      89.849271                             ON_STREAM_HRS^2
# 10     45.140379      ON_STREAM_HRS AVG_DOWNHOLE_TEMPERATURE
# 11     32.179811             ON_STREAM_HRS AVG_ANNULUS_PRESS
# 12     92.256449              ON_STREAM_HRS AVG_CHOKE_SIZE_P
# 13     15.629788                     ON_STREAM_HRS AVG_WHP_P
# 14     59.318521                     ON_STREAM_HRS AVG_WHT_P
# 15     10.671925                 ON_STREAM_HRS DP_CHOKE_SIZE
# 16    -17.555587                  ON_STREAM_HRS BORE_WAT_VOL
# 17    -14.040277                  AVG_DOWNHOLE_TEMPERATURE^2
# 18    -25.095811  AVG_DOWNHOLE_TEMPERATURE AVG_ANNULUS_PRESS
# 19     31.535868   AVG_DOWNHOLE_TEMPERATURE AVG_CHOKE_SIZE_P
# 20     -3.992092          AVG_DOWNHOLE_TEMPERATURE AVG_WHP_P
# 21    -15.566624          AVG_DOWNHOLE_TEMPERATURE AVG_WHT_P
# 22     57.517389      AVG_DOWNHOLE_TEMPERATURE DP_CHOKE_SIZE
# 23    -17.390061       AVG_DOWNHOLE_TEMPERATURE BORE_WAT_VOL
# 24    -57.299867                         AVG_ANNULUS_PRESS^2
# 25     31.017905          AVG_ANNULUS_PRESS AVG_CHOKE_SIZE_P
# 26      0.311978                 AVG_ANNULUS_PRESS AVG_WHP_P
# 27    -14.122946                 AVG_ANNULUS_PRESS AVG_WHT_P
# 28     70.954705             AVG_ANNULUS_PRESS DP_CHOKE_SIZE
# 29     -7.315320              AVG_ANNULUS_PRESS BORE_WAT_VOL

# %%
# get importance
importance = lin_reg.coef_
# summarize feature importance
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
# Out:
# Feature: 0, Score: 51.27224
# Feature: 1, Score: 98.31214
# Feature: 2, Score: -2.26809
# Feature: 3, Score: -33.30644
# Feature: 4, Score: 75.99493
# Feature: 5, Score: 21.82759
# Feature: 6, Score: 49.87776
# Feature: 7, Score: -15.09676
# Feature: 8, Score: 24.14009
# Feature: 9, Score: 89.84927
# Feature: 10, Score: 45.14038
# Feature: 11, Score: 32.17981
# Feature: 12, Score: 92.25645
# Feature: 13, Score: 15.62979
# Feature: 14, Score: 59.31852
# Feature: 15, Score: 10.67192
# Feature: 16, Score: -17.55559
# Feature: 17, Score: -14.04028
# Feature: 18, Score: -25.09581
# Feature: 19, Score: 31.53587
# Feature: 20, Score: -3.99209
# Feature: 21, Score: -15.56662
# Feature: 22, Score: 57.51739
# Feature: 23, Score: -17.39006
# Feature: 24, Score: -57.29987
# Feature: 25, Score: 31.01790
# Feature: 26, Score: 0.31198
# Feature: 27, Score: -14.12295
# Feature: 28, Score: 70.95471
# Feature: 29, Score: -7.31532
# Feature: 30, Score: 72.43979
# Feature: 31, Score: 19.13292
# Feature: 32, Score: 71.81763
# Feature: 33, Score: -7.77017
# Feature: 34, Score: 44.49828
# Feature: 35, Score: 25.38539
# Feature: 36, Score: 11.33974
# Feature: 37, Score: -0.46255
# Feature: 38, Score: 41.99049
# Feature: 39, Score: 22.88914
# Feature: 40, Score: -21.09927
# Feature: 41, Score: -86.86849
# Feature: 42, Score: 0.18719
# Feature: 43, Score: -0.68160
# Feature: 44, Score: -0.00745
# Feature: 45, Score: 96.67926
# Feature: 46, Score: 42.97591
# Feature: 47, Score: 30.48045
# Feature: 48, Score: 83.45223
# Feature: 49, Score: 19.87861
# Feature: 50, Score: 70.63802
# Feature: 51, Score: -59.93161
# Feature: 52, Score: -14.04479
# Feature: 53, Score: 43.62739
# Feature: 54, Score: 5.53604
# Feature: 55, Score: 52.00840
# Feature: 56, Score: 9.95531
# Feature: 57, Score: 28.72053
# Feature: 58, Score: 80.54117
# Feature: 59, Score: -13.04520
# Feature: 60, Score: 19.21065
# Feature: 61, Score: 28.38381
# Feature: 62, Score: 5.52824
# Feature: 63, Score: 24.99759
# Feature: 64, Score: 79.23440
# Feature: 65, Score: 5.11778
# Feature: 66, Score: 79.24722
# Feature: 67, Score: 21.49493
# Feature: 68, Score: 72.76161
# Feature: 69, Score: 322.98559
# Feature: 70, Score: -17.26930
# Feature: 71, Score: 10.30839
# Feature: 72, Score: 13.73383
# Feature: 73, Score: -33.92970
# Feature: 74, Score: 1.39393
# Feature: 75, Score: 56.17493
# Feature: 76, Score: -174.54081
# Feature: 77, Score: 60.57517
# Feature: 78, Score: -1.47032
# Feature: 79, Score: -0.14961
# Feature: 80, Score: 0.00351
# Feature: 81, Score: -15.32846
# Feature: 82, Score: -26.60112
# Feature: 83, Score: 29.03489
# Feature: 84, Score: -3.09323
# Feature: 85, Score: -14.34103
# Feature: 86, Score: -37.57719
# Feature: 87, Score: 17.32449
# Feature: 88, Score: -29.46828
# Feature: 89, Score: -1.36270
# Feature: 90, Score: -5.91767
# Feature: 91, Score: -33.26425
# Feature: 92, Score: 66.09667
# Feature: 93, Score: -5.55158
# Feature: 94, Score: 30.22508
# Feature: 95, Score: 9.82292
# Feature: 96, Score: 28.85331
# Feature: 97, Score: 42.12119
# Feature: 98, Score: 13.33749
# Feature: 99, Score: 12.48106
# Feature: 100, Score: -1.43955
# Feature: 101, Score: -64.29095
# Feature: 102, Score: 28.61110
# Feature: 103, Score: -26.53432
# Feature: 104, Score: 35.62567
# Feature: 105, Score: 7.00849
# Feature: 106, Score: -0.72429
# Feature: 107, Score: 0.13832
# Feature: 108, Score: 0.00239
# Feature: 109, Score: -43.99540
# Feature: 110, Score: 29.74509
# Feature: 111, Score: -1.97847
# Feature: 112, Score: -21.15067
# Feature: 113, Score: -138.24001
# Feature: 114, Score: -3.79039
# Feature: 115, Score: 33.02285
# Feature: 116, Score: 4.68632
# Feature: 117, Score: 21.80773
# Feature: 118, Score: -90.24769
# Feature: 119, Score: -5.92779
# Feature: 120, Score: 5.52225
# Feature: 121, Score: -3.17346
# Feature: 122, Score: -61.76578
# Feature: 123, Score: 102.14141
# Feature: 124, Score: -12.40689
# Feature: 125, Score: -87.00033
# Feature: 126, Score: -2.59313
# Feature: 127, Score: 0.84194
# Feature: 128, Score: -0.63129
# Feature: 129, Score: -0.00017
# Feature: 130, Score: 64.05090
# Feature: 131, Score: 16.23389
# Feature: 132, Score: 61.88026
# Feature: 133, Score: 27.82959
# Feature: 134, Score: -3.95933
# Feature: 135, Score: 6.97908
# Feature: 136, Score: 13.20272
# Feature: 137, Score: -34.14127
# Feature: 138, Score: -214.27244
# Feature: 139, Score: 50.19337
# Feature: 140, Score: 39.96511
# Feature: 141, Score: -32.03302
# Feature: 142, Score: 0.36780
# Feature: 143, Score: 0.61361
# Feature: 144, Score: 0.00364
# Feature: 145, Score: 12.46487
# Feature: 146, Score: 10.32406
# Feature: 147, Score: 273.54330
# Feature: 148, Score: -46.73148
# Feature: 149, Score: 6.70916
# Feature: 150, Score: -56.17174
# Feature: 151, Score: 20.58832
# Feature: 152, Score: -4.25587
# Feature: 153, Score: -2.51253
# Feature: 154, Score: 0.01811
# Feature: 155, Score: 19.78522
# Feature: 156, Score: -201.73572
# Feature: 157, Score: 78.07820
# Feature: 158, Score: 3.80481
# Feature: 159, Score: 2.13707
# Feature: 160, Score: 0.00344
# Feature: 161, Score: 0.01472
# Feature: 162, Score: 0.02175
# Feature: 163, Score: -0.00017
# Feature: 164, Score: 0.00000
# Feature: 165, Score: 82.63941
# Feature: 166, Score: 37.14046
# Feature: 167, Score: 16.61880
# Feature: 168, Score: 72.98613
# Feature: 169, Score: 17.80244
# Feature: 170, Score: 60.92825
# Feature: 171, Score: -39.99562
# Feature: 172, Score: 4.08603
# Feature: 173, Score: 42.77153
# Feature: 174, Score: -0.40891
# Feature: 175, Score: 43.23531
# Feature: 176, Score: 11.40457
# Feature: 177, Score: 31.71708
# Feature: 178, Score: -8.14761
# Feature: 179, Score: 5.66817
# Feature: 180, Score: 10.67022
# Feature: 181, Score: 20.32832
# Feature: 182, Score: 3.79263
# Feature: 183, Score: 18.33157
# Feature: 184, Score: 11.24625
# Feature: 185, Score: 3.76745
# Feature: 186, Score: 71.46844
# Feature: 187, Score: 16.77616
# Feature: 188, Score: 65.89953
# Feature: 189, Score: -67.42808
# Feature: 190, Score: 1.59694
# Feature: 191, Score: 13.60946
# Feature: 192, Score: 16.46779
# Feature: 193, Score: 128.32615
# Feature: 194, Score: -7.38804
# Feature: 195, Score: 58.93349
# Feature: 196, Score: 44.49815
# Feature: 197, Score: 7.22800
# Feature: 198, Score: -0.24227
# Feature: 199, Score: 0.05327
# Feature: 200, Score: -0.00212
# Feature: 201, Score: 42.05551
# Feature: 202, Score: 2.52741
# Feature: 203, Score: 50.13921
# Feature: 204, Score: 9.69806
# Feature: 205, Score: 29.00889
# Feature: 206, Score: 78.36008
# Feature: 207, Score: 12.69139
# Feature: 208, Score: 1.59067
# Feature: 209, Score: -0.26344
# Feature: 210, Score: -0.03731
# Feature: 211, Score: 1.43252
# Feature: 212, Score: -1.01823
# Feature: 213, Score: -0.06138
# Feature: 214, Score: 39.81690
# Feature: 215, Score: 12.15183
# Feature: 216, Score: 36.75070
# Feature: 217, Score: 217.41103
# Feature: 218, Score: -6.98621
# Feature: 219, Score: 8.69432
# Feature: 220, Score: 7.24763
# Feature: 221, Score: -48.55090
# Feature: 222, Score: 9.60596
# Feature: 223, Score: 26.86332
# Feature: 224, Score: -201.75243
# Feature: 225, Score: -4.60151
# Feature: 226, Score: -1.07292
# Feature: 227, Score: -0.18752
# Feature: 228, Score: -0.00019
# Feature: 229, Score: 17.13558
# Feature: 230, Score: 29.48791
# Feature: 231, Score: 5.16494
# Feature: 232, Score: 16.08357
# Feature: 233, Score: -55.36334
# Feature: 234, Score: 1.80370
# Feature: 235, Score: 29.42501
# Feature: 236, Score: 1.62704
# Feature: 237, Score: 21.22969
# Feature: 238, Score: -411.74906
# Feature: 239, Score: -5.23112
# Feature: 240, Score: 4.26166
# Feature: 241, Score: 3.81595
# Feature: 242, Score: -25.90126
# Feature: 243, Score: 19.84024
# Feature: 244, Score: 19.44103
# Feature: 245, Score: 100.39986
# Feature: 246, Score: -14.10619
# Feature: 247, Score: -0.15366
# Feature: 248, Score: -0.26789
# Feature: 249, Score: -0.00001
# Feature: 250, Score: 68.28059
# Feature: 251, Score: 17.75048
# Feature: 252, Score: 62.38404
# Feature: 253, Score: 121.44726
# Feature: 254, Score: -2.62468
# Feature: 255, Score: 8.01713
# Feature: 256, Score: 15.94686
# Feature: 257, Score: 19.22625
# Feature: 258, Score: 68.77667
# Feature: 259, Score: 59.38113
# Feature: 260, Score: 66.95054
# Feature: 261, Score: 6.09629
# Feature: 262, Score: -5.45172
# Feature: 263, Score: -0.43438
# Feature: 264, Score: 0.00175
# Feature: 265, Score: 7.98708
# Feature: 266, Score: 10.95612
# Feature: 267, Score: 252.64444
# Feature: 268, Score: 8.66344
# Feature: 269, Score: 15.04429
# Feature: 270, Score: 96.84476
# Feature: 271, Score: -82.23433
# Feature: 272, Score: -7.08294
# Feature: 273, Score: 2.73935
# Feature: 274, Score: 0.00940
# Feature: 275, Score: 52.51909
# Feature: 276, Score: 157.03504
# Feature: 277, Score: -25.94422
# Feature: 278, Score: 1.66791
# Feature: 279, Score: 0.21484
# Feature: 280, Score: -0.00259
# Feature: 281, Score: 0.06489
# Feature: 282, Score: -0.02106
# Feature: 283, Score: -0.00009
# Feature: 284, Score: -0.00000
# Feature: 285, Score: -13.19063
# Feature: 286, Score: -26.71828
# Feature: 287, Score: 27.38015
# Feature: 288, Score: -2.05506
# Feature: 289, Score: -12.90647
# Feature: 290, Score: -26.98504
# Feature: 291, Score: 0.20037
# Feature: 292, Score: -28.03414
# Feature: 293, Score: -2.00323
# Feature: 294, Score: -7.20113
# Feature: 295, Score: -31.74628
# Feature: 296, Score: -118.03508
# Feature: 297, Score: 2.20894
# Feature: 298, Score: 28.36850
# Feature: 299, Score: 8.65641
# Feature: 300, Score: 27.13154
# Feature: 301, Score: -46.60825
# Feature: 302, Score: -9.59002
# Feature: 303, Score: 11.79833
# Feature: 304, Score: -1.43152
# Feature: 305, Score: -48.54171
# Feature: 306, Score: -44.78932
# Feature: 307, Score: -23.04881
# Feature: 308, Score: -27.91192
# Feature: 309, Score: -8.84713
# Feature: 310, Score: 1.55455
# Feature: 311, Score: 0.16094
# Feature: 312, Score: -0.00090
# Feature: 313, Score: -14.64727
# Feature: 314, Score: 8.06838
# Feature: 315, Score: -1.23579
# Feature: 316, Score: -25.47055
# Feature: 317, Score: 10.06537
# Feature: 318, Score: 0.51833
# Feature: 319, Score: 2.12513
# Feature: 320, Score: -2.13403
# Feature: 321, Score: -3.94956
# Feature: 322, Score: -113.03749
# Feature: 323, Score: 1.94414
# Feature: 324, Score: 4.56445
# Feature: 325, Score: -5.78768
# Feature: 326, Score: 17.29805
# Feature: 327, Score: 1.77580
# Feature: 328, Score: -32.64211
# Feature: 329, Score: 113.17998
# Feature: 330, Score: 1.35626
# Feature: 331, Score: 0.18678
# Feature: 332, Score: 0.02239
# Feature: 333, Score: -0.00006
# Feature: 334, Score: 23.57861
# Feature: 335, Score: 9.13258
# Feature: 336, Score: 26.07493
# Feature: 337, Score: 60.01971
# Feature: 338, Score: 2.67438
# Feature: 339, Score: 6.25551
# Feature: 340, Score: 5.98649
# Feature: 341, Score: 57.32286
# Feature: 342, Score: 17.74408
# Feature: 343, Score: 19.35041
# Feature: 344, Score: -11.99302
# Feature: 345, Score: -7.93825
# Feature: 346, Score: -0.88836
# Feature: 347, Score: -0.16165
# Feature: 348, Score: -0.00015
# Feature: 349, Score: 8.92750
# Feature: 350, Score: 8.06150
# Feature: 351, Score: 245.79194
# Feature: 352, Score: 33.00104
# Feature: 353, Score: -0.83141
# Feature: 354, Score: 23.96613
# Feature: 355, Score: -13.41813
# Feature: 356, Score: -2.79276
# Feature: 357, Score: -0.93787
# Feature: 358, Score: -0.00448
# Feature: 359, Score: -23.86664
# Feature: 360, Score: -4.42139
# Feature: 361, Score: 8.14304
# Feature: 362, Score: -0.06157
# Feature: 363, Score: 0.08875
# Feature: 364, Score: -0.00028
# Feature: 365, Score: 0.00785
# Feature: 366, Score: 0.00577
# Feature: 367, Score: 0.00003
# Feature: 368, Score: 0.00000
# Feature: 369, Score: -27.24241
# Feature: 370, Score: 30.64767
# Feature: 371, Score: 0.86458
# Feature: 372, Score: -14.83810
# Feature: 373, Score: 45.27961
# Feature: 374, Score: -0.84380
# Feature: 375, Score: 27.56106
# Feature: 376, Score: 11.30732
# Feature: 377, Score: 23.47723
# Feature: 378, Score: 549.56282
# Feature: 379, Score: 1.66875
# Feature: 380, Score: 3.36541
# Feature: 381, Score: -1.84340
# Feature: 382, Score: 49.90565
# Feature: 383, Score: -5.46932
# Feature: 384, Score: -16.80150
# Feature: 385, Score: -63.77209
# Feature: 386, Score: 2.37691
# Feature: 387, Score: 0.12390
# Feature: 388, Score: 0.05495
# Feature: 389, Score: 0.00019
# Feature: 390, Score: 35.07981
# Feature: 391, Score: 5.95150
# Feature: 392, Score: 24.75999
# Feature: 393, Score: -123.26422
# Feature: 394, Score: 2.64870
# Feature: 395, Score: 1.12085
# Feature: 396, Score: 2.03409
# Feature: 397, Score: -114.84734
# Feature: 398, Score: 18.72545
# Feature: 399, Score: 15.03150
# Feature: 400, Score: -205.51734
# Feature: 401, Score: 1.55866
# Feature: 402, Score: 2.34211
# Feature: 403, Score: 0.05359
# Feature: 404, Score: -0.00071
# Feature: 405, Score: 4.80219
# Feature: 406, Score: 2.64217
# Feature: 407, Score: 151.34368
# Feature: 408, Score: -170.18742
# Feature: 409, Score: -1.52813
# Feature: 410, Score: -44.07627
# Feature: 411, Score: -17.96685
# Feature: 412, Score: -2.15341
# Feature: 413, Score: 1.56667
# Feature: 414, Score: -0.01142
# Feature: 415, Score: -11.31940
# Feature: 416, Score: 163.66767
# Feature: 417, Score: 1.40960
# Feature: 418, Score: -0.95397
# Feature: 419, Score: 0.13295
# Feature: 420, Score: 0.00403
# Feature: 421, Score: 0.00166
# Feature: 422, Score: -0.00138
# Feature: 423, Score: 0.00010
# Feature: 424, Score: -0.00000
# Feature: 425, Score: 61.04508
# Feature: 426, Score: 14.72036
# Feature: 427, Score: 55.70873
# Feature: 428, Score: 43.87843
# Feature: 429, Score: 3.13326
# Feature: 430, Score: 4.62204
# Feature: 431, Score: 12.41329
# Feature: 432, Score: -42.55644
# Feature: 433, Score: -20.57821
# Feature: 434, Score: 46.54954
# Feature: 435, Score: 16.39906
# Feature: 436, Score: 0.84134
# Feature: 437, Score: -1.22200
# Feature: 438, Score: 0.17383
# Feature: 439, Score: -0.00054
# Feature: 440, Score: 3.66121
# Feature: 441, Score: 4.86395
# Feature: 442, Score: 92.38222
# Feature: 443, Score: 340.71480
# Feature: 444, Score: 9.03855
# Feature: 445, Score: -61.14554
# Feature: 446, Score: 57.67961
# Feature: 447, Score: -1.79714
# Feature: 448, Score: -4.23683
# Feature: 449, Score: -0.01561
# Feature: 450, Score: 38.31983
# Feature: 451, Score: -120.28058
# Feature: 452, Score: 9.57834
# Feature: 453, Score: 0.99252
# Feature: 454, Score: 0.25000
# Feature: 455, Score: -0.00013
# Feature: 456, Score: 0.01370
# Feature: 457, Score: 0.01549
# Feature: 458, Score: 0.00008
# Feature: 459, Score: -0.00000
# Feature: 460, Score: 3.77295
# Feature: 461, Score: 7.77864
# Feature: 462, Score: 42.17977
# Feature: 463, Score: -125.59558
# Feature: 464, Score: 8.73838
# Feature: 465, Score: 226.39052
# Feature: 466, Score: -83.43295
# Feature: 467, Score: -4.29005
# Feature: 468, Score: 13.10761
# Feature: 469, Score: -0.02036
# Feature: 470, Score: 9.48511
# Feature: 471, Score: 64.04295
# Feature: 472, Score: 44.26281
# Feature: 473, Score: -1.90130
# Feature: 474, Score: -3.15511
# Feature: 475, Score: 0.00022
# Feature: 476, Score: 0.05722
# Feature: 477, Score: -0.16766
# Feature: 478, Score: 0.00023
# Feature: 479, Score: 0.00000
# Feature: 480, Score: 22.43468
# Feature: 481, Score: 188.55012
# Feature: 482, Score: -31.76821
# Feature: 483, Score: -1.80291
# Feature: 484, Score: -1.10120
# Feature: 485, Score: 0.00020
# Feature: 486, Score: -0.02586
# Feature: 487, Score: 0.02371
# Feature: 488, Score: 0.00010
# Feature: 489, Score: -0.00000
# Feature: 490, Score: -0.00019
# Feature: 491, Score: 0.00057
# Feature: 492, Score: -0.00000
# Feature: 493, Score: -0.00000
# Feature: 494, Score: 0.00000

# %%
# plot feature importance
plt.figure(figsize = (14,8))
plt.xlabel("Features")
plt.ylabel("Coeff. (Importance)")
plt.bar([x for x in range(len(importance))], importance)
plt.show()

# %%
y_pred = lin_reg.predict(x_pol_test)

# %%
print("The R2 value for Polynomial regression(4th order) for oil volume production is",lin_reg.score(x_pol_test, y_test_final))
# Out:
# The R2 value for Polynomial regression(4th order) for oil volume production is 0.9572677127294036

# %%
df = pd.DataFrame({'Real Values':y_test_final, 'Predicted Values':y_pred})
df.head(50)
# Out:
#       Real Values  Predicted Values
# 6805        643.0        494.551610
# 6756        613.0        230.907763
# 5221       4634.0       4416.488183
# 4435        688.0        651.846172
# 5261       3571.0       3576.853894
# ...           ...               ...
# 6176        928.0       1597.373273
# 4404        719.0        617.061145
# 4942          0.0       -104.375574
# 3628        575.0        506.797480
# 7692        181.0        147.469827
#
# [50 rows x 2 columns]

# %%
X_test.groupby(['NPD_WELL_BORE_CODE']).agg({"DATEPRD":"count"})
# Out:
#                     DATEPRD
# NPD_WELL_BORE_CODE
# 5351                    910
# 5599                    914
# 7078                    360

# %% [markdown]
# ## Actual V/S Model Prediction plot for Well No.- 5599

# %% [markdown]
# ### Linear Regression

# %%
X_test_5599 = X_test[X_test["NPD_WELL_BORE_CODE"] == 5599]

y_test_5599 = y_test[y_test["NPD_WELL_BORE_CODE"] == 5599]

x_test_5599final = X_test_5599.drop(['DATEPRD',"NPD_WELL_BORE_CODE"],axis = 1)


y_pred = reg_all.predict(x_test_5599final)
plt.style.use('fivethirtyeight')
plt.figure(figsize = (14,8))
plt.scatter(X_test_5599["DATEPRD"].tolist(),y_pred,label='predicted')
plt.scatter(X_test_5599["DATEPRD"].tolist(),y_test_5599['BORE_OIL_VOL'],label='actual')
plt.legend()
plt.xlabel("Year")
plt.ylabel("Bore oil volume")
plt.title('Actual v/s Linear Regression Model prediction for Bore Oil Volume for Well No. - 5599')

y_test_5599_final = y_test_5599['BORE_OIL_VOL']
print("The R2 value for linear regression for oil volume production in well 5599 is", reg_all.score(x_test_5599final,y_test_5599_final ))
# Out:
# The R2 value for linear regression for oil volume production in well 5599 is 0.5500832938872098

# %%
print("The linear model is: BORE_OIL_VOL = {:.5} + {:.5}*ON_STREAM_HRS + {:.5}*AVG_DOWNHOLE_TEMPERATURE  {:.5}*AVG_ANNULUS_PRESS + {:.5}*AVG_CHOKE_SIZE_P + {:.5}*AVG_WHP_P + {:.5}*AVG_WHT_P + {:.5}*DP_CHOKE_SIZE {:.5}*BORE_WAT_".format(reg_all.intercept_, reg_all.coef_[0], reg_all.coef_[1], reg_all.coef_[2],reg_all.coef_[3], reg_all.coef_[4], reg_all.coef_[5], reg_all.coef_[6], reg_all.coef_[7]))
# Out:
# The linear model is: BORE_OIL_VOL = -1110.7 + 1338.1*ON_STREAM_HRS + 280.89*AVG_DOWNHOLE_TEMPERATURE  -1194.4*AVG_ANNULUS_PRESS + 48.021*AVG_CHOKE_SIZE_P + 506.57*AVG_WHP_P + 2572.3*AVG_WHT_P + 13.055*DP_CHOKE_SIZE -0.40973*BORE_WAT_

# %%
X_test_5599 = X_test[X_test["NPD_WELL_BORE_CODE"] == 5599]

y_test_5599 = y_test[y_test["NPD_WELL_BORE_CODE"] == 5599]

x_test_5599final = X_test_5599.drop(['DATEPRD',"NPD_WELL_BORE_CODE"],axis = 1)

y_linear = reg_all.predict(x_test_5599final)


x_pol_test_5599 = poly_reg.fit_transform(x_test_5599final)
y_poly = lin_reg.predict(x_pol_test_5599)

plt.style.use('fivethirtyeight')
plt.figure(figsize = (14,8))
plt.scatter(X_test_5599["DATEPRD"].tolist(),y_linear,label='Linear Regression Model predicted')
plt.scatter(X_test_5599["DATEPRD"].tolist(),y_poly,label='Polynomial Regression(4 degree) predicted', color = 'green')
plt.scatter(X_test_5599["DATEPRD"].tolist(),y_test_5599['BORE_OIL_VOL'],label='actual', color = 'orange')
plt.legend()
plt.xlabel("Year")
plt.ylabel("Bore oil volume")
plt.title('Actual v/s Model prediction for Bore Oil Volume for Well No. - 5599')

print("The R2 value for linear regression for oil volume production in well 5599 is", reg_all.score(x_test_5599final,y_test_5599_final ))

print("The R2 value for Polynomial regression(Degree - 4) for oil volume production in well 5599 is", lin_reg.score(x_pol_test_5599,y_test_5599_final ))
# Out:
# The R2 value for linear regression for oil volume production in well 5599 is 0.5500832938872098
# The R2 value for Polynomial regression(Degree - 4) for oil volume production in well 5599 is 0.9691389819491184

# %% [markdown]
# ## Actual V/S Model Prediction plot for Well No.- 5351

# %% [markdown]
# ### Linear Regression

# %%
X_test_5351 = X_test[X_test["NPD_WELL_BORE_CODE"] == 5351]

y_test_5351 = y_test[y_test["NPD_WELL_BORE_CODE"] == 5351]

x_test_5351final = X_test_5351.drop(['DATEPRD',"NPD_WELL_BORE_CODE"],axis = 1)


y_pred = reg_all.predict(x_test_5351final)
plt.style.use('fivethirtyeight')
plt.figure(figsize = (14,8))
plt.scatter(X_test_5351["DATEPRD"].tolist(),y_pred,label='predicted')
plt.scatter(X_test_5351["DATEPRD"].tolist(),y_test_5351['BORE_OIL_VOL'],label='actual')
plt.legend()
plt.xlabel("Year")
plt.ylabel("Bore oil volume")
plt.title('Actual v/s Linear Regression Model prediction for Bore Oil Volume for Well No. - 5351')

y_test_5351_final = y_test_5351['BORE_OIL_VOL']
print("The R2 value for linear regression for oil volume production is", reg_all.score(x_test_5351final,y_test_5351_final ))
# Out:
# The R2 value for linear regression for oil volume production is 0.6750225210254919

# %%
X_test_5351 = X_test[X_test["NPD_WELL_BORE_CODE"] == 5351]

y_test_5351 = y_test[y_test["NPD_WELL_BORE_CODE"] == 5351]

x_test_5351final = X_test_5351.drop(['DATEPRD',"NPD_WELL_BORE_CODE"],axis = 1)

y_linear = reg_all.predict(x_test_5351final)


x_pol_test_5351 = poly_reg.fit_transform(x_test_5351final)
y_poly = lin_reg.predict(x_pol_test_5351)

plt.style.use('fivethirtyeight')
plt.figure(figsize = (14,8))
plt.scatter(X_test_5351["DATEPRD"].tolist(),y_linear,label='Linear Regression Model predicted')
plt.scatter(X_test_5351["DATEPRD"].tolist(),y_poly,label='Polynomial Regression(4 degree) predicted', color = 'green')
plt.scatter(X_test_5351["DATEPRD"].tolist(),y_test_5351['BORE_OIL_VOL'],label='actual', color = 'orange')
plt.legend()
plt.xlabel("Year")
plt.ylabel("Bore oil volume")
plt.title('Actual v/s Model prediction for Bore Oil Volume for Well No. - 5351')

print("The R2 value for linear regression for oil volume production in well 5351 is", reg_all.score(x_test_5351final,y_test_5351_final ))

print("The R2 value for Polynomial regression(Degree - 4) for oil volume production in well 5351 is", lin_reg.score(x_pol_test_5351,y_test_5351_final ))
# Out:
# The R2 value for linear regression for oil volume production in well 5351 is 0.6750225210254919
# The R2 value for Polynomial regression(Degree - 4) for oil volume production in well 5351 is 0.9475671886429053

# %% [markdown]
# ## Actual V/S Model Prediction plot for Well No.- 7078

# %% [markdown]
# ### Linear Regression

# %%
X_test_7078 = X_test[X_test["NPD_WELL_BORE_CODE"] == 7078]

y_test_7078 = y_test[y_test["NPD_WELL_BORE_CODE"] == 7078]

x_test_7078final = X_test_7078.drop(['DATEPRD',"NPD_WELL_BORE_CODE"],axis = 1)


y_pred = reg_all.predict(x_test_7078final)
plt.style.use('fivethirtyeight')
plt.figure(figsize = (14,8))
plt.scatter(X_test_7078["DATEPRD"].tolist(),y_pred,label='predicted')
plt.scatter(X_test_7078["DATEPRD"].tolist(),y_test_7078['BORE_OIL_VOL'],label='actual')
plt.legend()
plt.xlabel("Year")
plt.ylabel("Bore oil volume")
plt.title('Actual v/s Linear Regression Model prediction for Bore Oil Volume for Well No. - 7078')

y_test_7078_final = y_test_7078['BORE_OIL_VOL']
print("The R2 value for linear regression for oil volume production in well 7078 is", reg_all.score(x_test_7078final,y_test_7078_final ))
# Out:
# The R2 value for linear regression for oil volume production in well 7078 is -3.0140537511268564

# %%
X_test_7078 = X_test[X_test["NPD_WELL_BORE_CODE"] == 7078]

y_test_7078 = y_test[y_test["NPD_WELL_BORE_CODE"] == 7078]

x_test_7078final = X_test_7078.drop(['DATEPRD',"NPD_WELL_BORE_CODE"],axis = 1)

y_linear = reg_all.predict(x_test_7078final)


x_pol_test_7078 = poly_reg.fit_transform(x_test_7078final)
y_poly = lin_reg.predict(x_pol_test_7078)

plt.style.use('fivethirtyeight')
plt.figure(figsize = (14,8))
plt.scatter(X_test_7078["DATEPRD"].tolist(),y_linear,label='Linear Regression Model predicted')
plt.scatter(X_test_7078["DATEPRD"].tolist(),y_poly,label='Polynomial Regression(4 degree) predicted', color = 'green')
plt.scatter(X_test_7078["DATEPRD"].tolist(),y_test_7078['BORE_OIL_VOL'],label='actual', color = 'orange')
plt.legend()
plt.xlabel("Year")
plt.ylabel("Bore oil volume")
plt.title('Actual v/s Model prediction for Bore Oil Volume for Well No. - 7078')

print("The R2 value for linear regression for oil volume production in well 7078 is", reg_all.score(x_test_7078final,y_test_7078_final ))

print("The R2 value for Polynomial regression(Degree - 4) for oil volume production in well 7078 is", lin_reg.score(x_pol_test_7078,y_test_7078_final ))
# Out:
# The R2 value for linear regression for oil volume production in well 7078 is -3.0140537511268564
# The R2 value for Polynomial regression(Degree - 4) for oil volume production in well 7078 is 0.6541672406806815
